# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(16, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
df_fis
# Out:
#     Qt_acertos
# 0            0
# 1            3
# 2            9
# 3            5
# 4            5
# ..         ...
# 95          11
# 96          10
# 97           3
# 98           7
# 99          11
#
# [100 rows x 1 columns]

# %%
#Consolidando os DFs e exibindo a quantidade de acertos de cada disciplina

df_Acertos = pd.DataFrame({
    'Matemática':(df_mat['Qt_acertos']),
    'Português':(df_por['Qt_acertos']),
    'Geografia':(df_geo['Qt_acertos']),
    'Inglês':(df_ing['Qt_acertos']),
    'História':(df_his['Qt_acertos']),
    'Física':(df_fis['Qt_acertos']),
    'Química':(df_qui['Qt_acertos'])
})

df_Acertos
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 0            6         14          3       5         5       0        1
# 1           14         13          5       3         4       3        2
# 2           10          2          6       4         5       9       11
# 3            7          0          1       4         4       5        0
# 4            6          4          2       7         5       5        0
# ..         ...        ...        ...     ...       ...     ...      ...
# 95           7          0          3       0         4      11        6
# 96           2         13          0       7         5      10        4
# 97           0          0          1       0         1       3        9
# 98           2          9          0       3         1       7        9
# 99           4          3          7       3         5      11        6
#
# [100 rows x 7 columns]

# %%
# 1) (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.

df_percentuais = pd.DataFrame({
    'Matemática':(df_mat['Qt_acertos'] / 24)*100,
    'Português':(df_por['Qt_acertos'] / 18)*100,
    'Geografia':(df_geo['Qt_acertos'] / 8)*100,
    'Inglês':(df_ing['Qt_acertos'] / 8)*100,
    'História':(df_his['Qt_acertos'] / 8)*100,
    'Física':(df_fis['Qt_acertos'] / 12)*100,
    'Química':(df_qui['Qt_acertos'] / 12)*100
})
df_percentuais
# Out:
#     Matemática  Português  Geografia  Inglês  História     Física    Química
# 0    25.000000  77.777778       37.5    62.5      62.5   0.000000   8.333333
# 1    58.333333  72.222222       62.5    37.5      50.0  25.000000  16.666667
# 2    41.666667  11.111111       75.0    50.0      62.5  75.000000  91.666667
# 3    29.166667   0.000000       12.5    50.0      50.0  41.666667   0.000000
# 4    25.000000  22.222222       25.0    87.5      62.5  41.666667   0.000000
# ..         ...        ...        ...     ...       ...        ...        ...
# 95   29.166667   0.000000       37.5     0.0      50.0  91.666667  50.000000
# 96    8.333333  72.222222        0.0    87.5      62.5  83.333333  33.333333
# 97    0.000000   0.000000       12.5     0.0      12.5  25.000000  75.000000
# 98    8.333333  50.000000        0.0    37.5      12.5  58.333333  75.000000
# 99   16.666667  16.666667       87.5    37.5      62.5  91.666667  50.000000
#
# [100 rows x 7 columns]

# %%
# 2) (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
df_total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
df_total
# Out:
#     Qt_acertos
# 0           34
# 1           44
# 2           47
# 3           21
# 4           29
# ..         ...
# 95          31
# 96          41
# 97          14
# 98          31
# 99          39
#
# [100 rows x 1 columns]

# %%
# 3) Calcule o porcentual geral de cada aluno.
df_percentual_geral = (df_total / 90)*100
df_percentual_geral
# Out:
#     Qt_acertos
# 0    37.777778
# 1    48.888889
# 2    52.222222
# 3    23.333333
# 4    32.222222
# ..         ...
# 95   34.444444
# 96   45.555556
# 97   15.555556
# 98   34.444444
# 99   43.333333
#
# [100 rows x 1 columns]

# %%
# 4) Suponha que a nota de corte para a segunda fase seja 45. 
#Quantos alunos tiveram nota maior que 45?
total_gt_45 = df_total[df_total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    19
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. 
#Monte um novo DataFrame com os alunos desqualificados por este critério.

#dataframe com o total das as notas dos desqualificados

df_desqualificados_total = df_total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_desqualificados_total
# Out:
#     Qt_acertos
# 0           34
# 3           21
# 4           29
# 8           42
# 10          23
# 11          37
# 14          35
# 22          26
# 27          45
# 41          42
# 44          35
# 48          31
# 50          43
# 52          25
# 58          30
# 64          42
# 65          23
# 69          40
# 71          26
# 72          33
# 73          41
# 80          25
# 87          41
# 90          38
# 94          37
# 97          14

# %%
# Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. 
#Monte um novo DataFrame com os alunos desqualificados por este critério.

#dataframe com  as notas dos desqualificados com todas as disciplinas

df_desqualificados = df_Acertos[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_desqualificados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 0            6         14          3       5         5       0        1
# 3            7          0          1       4         4       5        0
# 4            6          4          2       7         5       5        0
# 8            7         13          7       0         4       0       11
# 10           1         10          2       2         4       4        0
# 11          11          8          0       7         0      11        0
# 14           0          9          3       3         6       4       10
# 22          11          0          5       0         7       3        0
# 27           6         13          7       3         7       0        9
# 41          16          5          3       5         5       0        8
# 44           7          9          5       4         6       0        4
# 48           9          4          7       3         1       7        0
# ...

# %%
#2) Quantos são esses alunos?

#df_eliminados.shape --> Retorna a quantidade de linhas e coluna do dataframe
len(df_desqualificados.index) #--> Retorna a quantidade de linhas do dataframe
#df_desqualificados_total.count()
# Out:
# 26

# %%
#3) Qual a média desses alunos em história e geografia?

# Exibe a média de todas as disciplinas dos desqualificados

df = pd.DataFrame(df_desqualificados)
media = df.mean()
media
# Out:
# Matemática    6.730769
# Português     8.461538
# Geografia     3.384615
# Inglês        3.923077
# História      3.692308
# Física        2.884615
# Química       3.923077
# dtype: float64

# %%
#3) Qual a média desses alunos em história?

df_desqualificados['História'].mean()
# Out:
# 3.6923076923076925

# %%
#3) Qual a média desses alunos em geografia?

df_desqualificados['Geografia'].mean()
# Out:
# 3.3846153846153846

# %%
#4) Monte um DataFrame com os alunos que passaram para a segunda fase. 
#Repare que estes alunos não podem ter sido desqualificados.

df_aprovados_2f = df_Acertos[(df_mat['Qt_acertos'] != 0) & 
                      (df_fis['Qt_acertos'] != 0) & 
                      (df_qui['Qt_acertos'] != 0)]
df_aprovados_2f
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 1           14         13          5       3         4       3        2
# 2           10          2          6       4         5       9       11
# 5           10          9          0       2         2      10        2
# 6           10          6          4       6         3      11       10
# 7            3         14          0       0         0       4        4
# ..         ...        ...        ...     ...       ...     ...      ...
# 93           2          8          0       2         6       1        6
# 95           7          0          3       0         4      11        6
# 96           2         13          0       7         5      10        4
# 98           2          9          0       3         1       7        9
# 99           4          3          7       3         5      11        6
#
# [74 rows x 7 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'

# %%
df_acre = pd.read_csv('registros_vacinacao_ACRE.csv', sep=';')
df_acre
# Out:
#                                       document_id  \
# 0       b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1       a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2       af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3       4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4       000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
# ...                                           ...
# 169066  1d8f6ea9-d3f5-4882-9fe4-9d2f3ef88d77-i0b0
# 169067  77ff98a4-79fb-47c9-aafa-8bf45708c4bc-i0b0
# 169068  1da067bc-9989-4fa4-8838-e1e40cdfeebf-i0b0
# 169069  eacc22e0-6f78-460f-a8e7-d85c6129951e-i0b0
# 169070  02795bd0-b1a7-49c1-83ca-90a9f9b4b794-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1       f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2       6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# ...

# %%
df_acre.head(5)
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  84a341fd350c1ba7117fccbb4d2df417bc0fac0fffac37...              51
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1939-11-22                          M                        3
# ...

# %%
df_acre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169071 entries, 0 to 169070
# Data columns (total 34 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               169071 non-null  object
#  1   paciente_id                               169071 non-null  object
#  2   paciente_idade                            169071 non-null  int64
#  3   paciente_datanascimento                   169071 non-null  object
#  4   paciente_enumsexobiologico                169071 non-null  object
#  5   paciente_racacor_codigo                   169071 non-null  int64
#  6   paciente_racacor_valor                    169071 non-null  object
#  7   paciente_endereco_coibgemunicipio         167802 non-null  float64
#  8   paciente_endereco_copais                  167804 non-null  float64
#  9   paciente_endereco_nmmunicipio             167804 non-null  object
# ...

# %%
# 1) Quantas vacinas estão registradas nessa base?

df_acre['vacina_nome'].unique() #exibe o valor único
# Out:
# array(['Covid-19-Coronavac-Sinovac/Butantan',
#        'Vacina Covid-19 - Covishield', 'Covid-19-AstraZeneca',
#        'Vacina covid-19 - BNT162b2 - BioNTech/Fosun Pharma/Pfizer',
#        'Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag'], dtype=object)

# %%
df_acre['vacina_nome'].nunique() #exibe a quantidade do valor único
# Out:
# 5

# %%
# 2) Quantos pacientes foram vacinados? (considere um paciente para cada valor único de paciente_id)

df_acre['paciente_id'].nunique()
# Out:
# 120517

# %%
# 3) Quantos pacientes únicos tomaram a primeira dose? 
#OBS: Há um caractere especial neste campo. Receba os valores do campo com o método .unique().

df_acre['vacina_descricao_dose'].value_counts()
# Out:
#     1ª Dose    120939
#     2ª Dose     48107
#     Dose           25
# Name: vacina_descricao_dose, dtype: int64

# %%
# 3.1) solução alternativa

#Criei a coluna 1a_dose e inseri 1 
#para os valores que correspondesse a '1ª dose' da coluna vacina_descricao_dose

df_acre['1a_dose'] = 0

# %%
# 3.1) solução alternativa

#Inseri 1 para os valores que correspondesse a '1ª dose' da coluna vacina_descricao_dose

df_acre.loc[df_acre['vacina_descricao_dose'] == '\xa0\xa0\xa0\xa01ª\xa0Dose', '1a_dose'] = 1

# %%
df_acre[['vacina_descricao_dose','1a_dose']]
# Out:
#        vacina_descricao_dose  1a_dose
# 0                    1ª Dose        1
# 1                    2ª Dose        0
# 2                    1ª Dose        1
# 3                    2ª Dose        0
# 4                    1ª Dose        1
# ...                      ...      ...
# 169066               1ª Dose        1
# 169067               1ª Dose        1
# 169068               1ª Dose        1
# 169069               1ª Dose        1
# 169070               1ª Dose        1
#
# [169071 rows x 2 columns]

# %%
# 3.1) solução alternativa

#Somei os valores da coluna '1ª dose' e é igual ao valor dado no count da solução acima

df_acre['1a_dose'].sum()
# Out:
# 120939

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados?

df_menor = df_acre[df_acre["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 47

# %%
# 4) solução alternativa

df_menor = df_acre[df_acre["paciente_idade"]<18]
df_menor['paciente_idade'].value_counts() 

# OBSERVE: que o paciente que tomou mais de uma vacina não é contado de novo
#OBSERVE: que 3 pacientes o valor é igual a 'zero'. Nesse caso, é um paciente com menos de 1 ano? 
# Ou é paciente que não informou a idade?
# Out:
# 17    30
# 16    12
# 13     4
# 0      3
# 12     2
# 3      1
# 8      1
# 1      1
# 14     1
# Name: paciente_idade, dtype: int64

# %%
# 4.1) continuação da solução alternativa acima

df_menor = df_acre[df_acre["paciente_idade"]<18]
df_menor['paciente_idade'].value_counts().sum() #TOTAL da quantidade acima
# Out:
# 55

# %%
# 5) Quantos estabelecimentos aplicaram vacina no Acre?

df_acre['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) crie uma cópia do DataFrame original, contendo somente os registros de vacinas realizadas 
# a menores de 18 anos.

df_menor18 = df_acre[df_acre["paciente_idade"]<18].copy()
df_menor18.head()
# Out:
#                                      document_id  \
# 1567   fdca313f-b348-422d-94d4-f2c66a87868c-i0b0
# 6250   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 9569   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 11338  647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 15144  7f469e03-bece-49d0-bebc-33ad98e27f54-i0b0
#
#                                              paciente_id  paciente_idade  \
# 1567   f5e6b8c44f7c4d13a87c582def5e8d460435b02f26af8c...              17
# 6250   e1a45c07e3c393d5f0eccf4204a7ceab338f4f06696ecb...              16
# 9569   7cf3b238383a70eeb26841c01817737c9706d5b231e8c2...              17
# 11338  53eb7fed5faa26ad17ce21ee378f28e25399ab7e90bc05...              17
# 15144  dbaa6420d8a815158387668d0a59a19cf2bb63958e35d1...              16
#
#       paciente_datanascimento paciente_enumsexobiologico  \
# 1567               2003-07-18                          F
# 6250               2004-05-18                          M
# ...

# %%
df_menor18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 1567 to 164449
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   document_id                               55 non-null     object
#  1   paciente_id                               55 non-null     object
#  2   paciente_idade                            55 non-null     int64
#  3   paciente_datanascimento                   55 non-null     object
#  4   paciente_enumsexobiologico                55 non-null     object
#  5   paciente_racacor_codigo                   55 non-null     int64
#  6   paciente_racacor_valor                    55 non-null     object
#  7   paciente_endereco_coibgemunicipio         52 non-null     float64
#  8   paciente_endereco_copais                  52 non-null     float64
#  9   paciente_endereco_nmmunicipio             52 non-null     object
# ...

# %%
# 2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()

lista_colunas = df_menor18.columns.unique()
lista_colunas
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.

df_menor18['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, 
# faça uma lista com esses valores.

lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
df_menor_lista = lista_variaveis
df_menor_lista
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaosocial',
#  'estalecimento_nofantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5) usando o método .loc, selecione somente essas variáveis

df_menor_lista2 = df_menor18.loc[:,'estabelecimento_valor':'estabelecimento_uf']

# %%
df_menor_lista2
# Out:
#         estabelecimento_valor  \
# 1567                  2001314
# 6250                  6917291
# 9569                  6159087
# 11338                 2000040
# 15144                 7625855
# 17153                 6748759
# 18361                 6308740
# 18608                 2001748
# 20204                 6917682
# 20759                 6917291
# 21119                 6428940
# 27860                 7625855
# 29127                 6612385
# 31200                 7625855
# 35654                 6159087
# 38412                 6159087
# 51872                 2000040
# 57405                 9648968
# 61131                 6430201
# 62742                 6917291
# 66922                 7625855
# 68290                 6955525
# 69882                 5336171
# 70881                 6697151
# 75368                 6748759
# 78289                 6430201
# 79146                 2001748
# 81424                 6955525
# 84331                 2001748
# 88619                 6430201
# ...

# %%
# 5) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento,
# com os dados do estabelecimento

df_menor_lista = df_menor_lista2.drop_duplicates()
df_menor_lista.shape #(18, 6)
# Out:
# (18, 6)

# %%
df_menor_lista.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 1567 to 140895
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   estabelecimento_valor             18 non-null     int64
#  1   estabelecimento_razaosocial       18 non-null     object
#  2   estalecimento_nofantasia          18 non-null     object
#  3   estabelecimento_municipio_codigo  18 non-null     int64
#  4   estabelecimento_municipio_nome    18 non-null     object
#  5   estabelecimento_uf                18 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1008.0+ bytes

# %%
# 5) ... e crie uma lista com uma linha para cada estabelecimento com os dados do estabelecimento
df_menor_lista.T
# Out:
#                                                                   1567    \
# estabelecimento_valor                                            2001314
# estabelecimento_razaosocial       PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# estalecimento_nofantasia                         ESF JOAO ALVES DA SILVA
# estabelecimento_municipio_codigo                                  120025
# estabelecimento_municipio_nome                            EPITACIOLANDIA
# estabelecimento_uf                                                    AC
#
#                                                                              6250    \
# estabelecimento_valor                                                       6917291
# estabelecimento_razaosocial                      PREFEITURA MUNICIPAL DE RIO BRANCO
# estalecimento_nofantasia          DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# estabelecimento_municipio_codigo                                             120040
# ...
